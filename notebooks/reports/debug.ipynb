# %%
import sys
from pathlib import Path

project_root = Path(r"C:\Proyectos\eeg_hmm_plattform")

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
import src.features

from src.features.registry import REGISTRY

REGISTRY.print_summary()
# Out:
# ============================================================
#   Feature Registry — 6 features registradas
# ============================================================
#
#   [SPECTRAL]
#     ⚠️  alpha_envelope                 [log_zscore]    n_ch
#     ⚠️  beta_envelope                  [log_zscore]    n_ch
#     ✅ theta_envelope                 [zscore]        n_ch
#
#   [TEMPORAL]
#     ⚠️  hjorth_complexity              [zscore]        n_ch
#     ✅ hjorth_mobility                [zscore]        n_ch
#     ⚠️  temporal_entropy               [robust_zscore] n_ch
#
#   Leyenda: ✅ alta suitability HMM | ⚠️  media | ❌ baja
# ============================================================
