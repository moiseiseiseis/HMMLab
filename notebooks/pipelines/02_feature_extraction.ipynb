# %%
import numpy as np
import matplotlib.pyplot as plt

# Verificar el shape del Mega Vector
features = np.load("../../data/interim/features/task/SUJETO_1_features.npy")
print(f"Shape del Mega Vector: {features.shape} (Ventanas x {features.shape[1]} features)")

plt.plot(features[:, 0]) # Graficar la potencia Theta de Fp1 a lo largo del tiempo
plt.title("Dinámica de Potencia Theta (Ventana a Ventana)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Verificar el shape del Mega Vector
# ----> 5 features = np.load("../../data/interim/features/task/SUJETO_1_features.npy")
#       6 print(f"Shape del Mega Vector: {features.shape} (Ventanas x {features.shape[1]} features)")
#       8 plt.plot(features[:, 0]) # Graficar la potencia Theta de Fp1 a lo largo del tiempo
#
# File c:\Users\pokem\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# ...
