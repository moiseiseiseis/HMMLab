# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt

exp_dir = "../../outputs/processed/experiments/feature_hmm/task/feat_task_k3_diag_pca90/"

# 1. Auditoría del PCA
pca = joblib.load(exp_dir + "pca_model.pkl")
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title("Varianza Retenida (PCA)")
plt.show()

# 2. Auditoría del HMM
model = joblib.load(exp_dir + "hmm_model.pkl")
print("Matriz de Transición:")
print(np.round(model.transmat_, 3))
# Out:
# Matriz de Transición:
# [[0.653 0.326 0.02 ]
#  [0.058 0.623 0.318]
#  [0.001 0.214 0.784]]
